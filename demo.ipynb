# %% [markdown]
# <a href="https://colab.research.google.com/github/harnalashok/LLMs/blob/main/demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 0.0 No need to install transformers
#     Comes preinstalled in colab:

from transformers import AutoTokenizer, AutoModelForMaskedLM

# %%
# 1.0 Set environment variables
import os
os.environ["HF_HOME"] = "/content/hf/misc"
os.environ["HF_DATASETS_CACHE"] = "/content/hf/datasets"
os.environ["TRANSFORMERS_CACHE"] = "/content/hf/models"

# %%
# 1.0.1 Create folders (not needed though):

# !mkdir -p /content/hf/misc
# !mkdir /content/hf/datasets
# !mkdir /content/hf/models

# %%
# 1.0.2 Check
print(os.environ["HF_HOME"])
# Out:
# /content/hf/misc

# %%
# 1.0.3 But downlaoded models are still saved to:
# /root/.cache/huggingface/hub/

tokenizer = AutoTokenizer.from_pretrained("bert-base-uncased")

model = AutoModelForMaskedLM.from_pretrained("bert-base-uncased")
# Out:
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForMaskedLM: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight', 'cls.seq_relationship.bias', 'cls.seq_relationship.weight']
# - This IS expected if you are initializing BertForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
# 2.0 This time they get saved to HF_HOME
! huggingface-cli download bert-base-uncased
# Out:
# Fetching 16 files:   0% 0/16 [00:00<?, ?it/s]Downloading 'coreml/fill-mask/float32_model.mlpackage/Data/com.apple.CoreML/weights/weight.bin' to '/content/hf/misc/hub/models--bert-base-uncased/blobs/c0c9f4914b4f0053785e96b8583cd59cda63c2f1b6e95a03970d772bf097e289.incomplete'
# Downloading 'LICENSE' to '/content/hf/misc/hub/models--bert-base-uncased/blobs/f49a4e16e68b128803cc2dcea614603632b04eac.incomplete'
# Downloading 'README.md' to '/content/hf/misc/hub/models--bert-base-uncased/blobs/40a2aaca31dd005eb5f6ffad07b5ffed0a31d1f6.incomplete'
# Downloading 'config.json' to '/content/hf/misc/hub/models--bert-base-uncased/blobs/45a2321a7ecfdaaf60a6c1fd7f5463994cc8907d.incomplete'
# Downloading 'flax_model.msgpack' to '/content/hf/misc/hub/models--bert-base-uncased/blobs/ea201fabe466ef7182f1f687fb5be4b62a73d3a78883f11264ff7f682cdb54bf.incomplete'
# Downloading '.gitattributes' to '/content/hf/misc/hub/models--bert-base-uncased/blobs/505a7adf8be9e5fdf06aabbfbe9046e6c811f91b.incomplete'
# Downloading 'coreml/fill-mask/float32_model.mlpackage/Manifest.json' to '/content/hf/misc/hub/models--bert-base-uncased/blobs/c1c37cd58b9eb000ddbb7ca90f04b893a33e50c8.incomplete'
# Downloading 'coreml/fill-mask/float32_model.mlpackage/Data/com.apple.CoreML/model.mlmodel' to '/content/hf/misc/hub/models--bert-base-uncased/blobs/bd3e35c1681371542bd98f96b299be1832d89dbf.incomplete'
#
# LICENSE: 100% 11.4k/11.4k [00:00<00:00, 38.8MB/s]
# Download complete. Moving file to /content/hf/misc/hub/models--bert-base-uncased/blobs/f49a4e16e68b128803cc2dcea614603632b04eac
#
# README.md: 100% 10.5k/10.5k [00:00<00:00, 39.1MB/s]
# Download complete. Moving file to /content/hf/misc/hub/models--bert-base-uncased/blobs/40a2aaca31dd005eb5f6ffad07b5ffed0a31d1f6
#
# config.json: 100% 570/570 [00:00<00:00, 2.92MB/s]
# Download complete. Moving file to /content/hf/misc/hub/models--bert-base-uncased/blobs/45a2321a7ecfdaaf60a6c1fd7f5463994cc8907d
#
# (…)kage/Data/com.apple.CoreML/model.mlmodel:   0% 0.00/165k [00:00<?, ?B/s]
#
# (…)sk/float32_model.mlpackage/Manifest.json: 100% 617/617 [00:00<00:00, 3.36MB/s]
# Download complete. Moving file to /content/hf/misc/hub/models--bert-base-uncased/blobs/c1c37cd58b9eb000ddbb7ca90f04b893a33e50c8
# Downloading 'model.onnx' to '/content/hf/misc/hub/models--bert-base-uncased/blobs/44d7a2896d341c51fb1eba89aea3a590e6af0ce33e25481136f7eeecb62e5f7f.incomplete'
# Downloading 'model.safetensors' to '/content/hf/misc/hub/models--bert-base-uncased/blobs/68d45e234eb4a928074dfd868cead0219ab85354cc53d20e772753c6bb9169d3.incomplete'
# Downloading 'pytorch_model.bin' to '/content/hf/misc/hub/models--bert-base-uncased/blobs/097417381d6c7230bd9e3557456d726de6e83245ec8b24f529f60198a67b203a.incomplete'
# (…)kage/Data/com.apple.CoreML/model.mlmodel: 100% 165k/165k [00:00<00:00, 2.77MB/s]
# Download complete. Moving file to /content/hf/misc/hub/models--bert-base-uncased/blobs/bd3e35c1681371542bd98f96b299be1832d89dbf
# Downloading 'rust_model.ot' to '/content/hf/misc/hub/models--bert-base-uncased/blobs/afd9aa425fd45c5655d3d43a0d041f9b76729bf475d6c017a0e9304a38f89972.incomplete'
#
# .gitattributes: 100% 491/491 [00:00<00:00, 2.02MB/s]
# Download complete. Moving file to /content/hf/misc/hub/models--bert-base-uncased/blobs/505a7adf8be9e5fdf06aabbfbe9046e6c811f91b
# Fetching 16 files:   6% 1/16 [00:00<00:11,  1.33it/s]Downloading 'tf_model.h5' to '/content/hf/misc/hub/models--bert-base-uncased/blobs/a7a17d6d844b5de815ccab5f42cad6d24496db3850a2a43d8258221018ce87d2.incomplete'
# Downloading 'tokenizer.json' to '/content/hf/misc/hub/models--bert-base-uncased/blobs/949a6f013d67eb8a5b4b5b46026217b888021b88.incomplete'
#
# tokenizer.json: 100% 466k/466k [00:00<00:00, 6.07MB/s]
# Download complete. Moving file to /content/hf/misc/hub/models--bert-base-uncased/blobs/949a6f013d67eb8a5b4b5b46026217b888021b88
#
# flax_model.msgpack:   0% 0.00/438M [00:00<?, ?B/s]
#
# weight.bin:   0% 0.00/532M [00:00<?, ?B/s]
#
#
# model.safetensors:   0% 0.00/440M [00:00<?, ?B/s]Downloading 'tokenizer_config.json' to '/content/hf/misc/hub/models--bert-base-uncased/blobs/e5c73d8a50df1f56fb5b0b8002d7cf4010afdccb.incomplete'
#
#
#
#
# tokenizer_config.json: 100% 48.0/48.0 [00:00<00:00, 238kB/s]
# Download complete. Moving file to /content/hf/misc/hub/models--bert-base-uncased/blobs/e5c73d8a50df1f56fb5b0b8002d7cf4010afdccb
# Downloading 'vocab.txt' to '/content/hf/misc/hub/models--bert-base-uncased/blobs/fb140275c155a9c7c5a3b3e0e77a9e839594a938.incomplete'
#
#
#
#
# model.onnx:   0% 0.00/532M [00:00<?, ?B/s]
#
#
#
#
# pytorch_model.bin:   0% 0.00/440M [00:00<?, ?B/s]
#
#
# model.safetensors:   2% 10.5M/440M [00:00<00:08, 48.5MB/s]
# flax_model.msgpack:   2% 10.5M/438M [00:00<00:10, 40.2MB/s]
#
# weight.bin:   2% 10.5M/532M [00:00<00:12, 40.4MB/s]
#
#
#
#
#
# vocab.txt:   0% 0.00/232k [00:00<?, ?B/s]
#
#
#
#
#
#
# vocab.txt: 100% 232k/232k [00:00<00:00, 9.31MB/s]
# Download complete. Moving file to /content/hf/misc/hub/models--bert-base-uncased/blobs/fb140275c155a9c7c5a3b3e0e77a9e839594a938
#
#
#
# model.safetensors:   5% 21.0M/440M [00:00<00:06, 65.3MB/s]
#
# weight.bin:   4% 21.0M/532M [00:00<00:08, 61.5MB/s]
#
#
#
#
#
# tf_model.h5:   0% 0.00/536M [00:00<?, ?B/s]
# flax_model.msgpack:   5% 21.0M/438M [00:00<00:08, 51.9MB/s]
#
#
#
# model.onnx:   2% 10.5M/532M [00:00<00:16, 31.1MB/s]
#
#
# model.safetensors:   7% 31.5M/440M [00:00<00:06, 59.9MB/s]
#
# weight.bin:   6% 31.5M/532M [00:00<00:08, 61.9MB/s]
#
#
#
#
# pytorch_model.bin:   2% 10.5M/440M [00:00<00:17, 24.3MB/s]
# flax_model.msgpack:   7% 31.5M/438M [00:00<00:09, 44.1MB/s]
#
#
#
#
#
#
# rust_model.ot:   2% 10.5M/534M [00:00<00:22, 22.9MB/s]
#
# weight.bin:   8% 41.9M/532M [00:00<00:09, 52.2MB/s]
#
#
# model.safetensors:  10% 41.9M/440M [00:00<00:07, 50.8MB/s]
#
#
#
#
#
# tf_model.h5:   2% 10.5M/536M [00:00<00:24, 21.8MB/s]
#
#
#
# model.onnx:   4% 21.0M/532M [00:00<00:18, 27.0MB/s]
# flax_model.msgpack:  10% 41.9M/438M [00:00<00:09, 41.5MB/s]
#
#
#
#
# pytorch_model.bin:   5% 21.0M/440M [00:00<00:16, 25.5MB/s]
#
# weight.bin:  10% 52.4M/532M [00:01<00:10, 45.0MB/s]
#
#
#
#
#
#
# rust_model.ot:   4% 21.0M/534M [00:00<00:19, 26.9MB/s]
#
#
# model.safetensors:  12% 52.4M/440M [00:01<00:09, 42.1MB/s]
#
#
#
#
#
# tf_model.h5:   4% 21.0M/536M [00:00<00:18, 28.5MB/s]
# flax_model.msgpack:  12% 52.4M/438M [00:01<00:08, 43.4MB/s]
#
#
#
# model.onnx:   6% 31.5M/532M [00:01<00:15, 32.2MB/s]
#
#
#
#
# pytorch_model.bin:   7% 31.5M/440M [00:01<00:12, 33.3MB/s]
#
# weight.bin:  12% 62.9M/532M [00:01<00:10, 45.1MB/s]
#
#
# model.safetensors:  14% 62.9M/440M [00:01<00:08, 44.1MB/s]
#
#
#
#
#
#
# rust_model.ot:   6% 31.5M/534M [00:01<00:15, 32.4MB/s]
#
#
#
#
#
# tf_model.h5:   6% 31.5M/536M [00:01<00:15, 32.9MB/s]
# flax_model.msgpack:  14% 62.9M/438M [00:01<00:08, 43.6MB/s]
#
# weight.bin:  14% 73.4M/532M [00:01<00:09, 48.1MB/s]
#
#
#
# model.onnx:   8% 41.9M/532M [00:01<00:15, 32.4MB/s]
#
#
#
#
# pytorch_model.bin:  10% 41.9M/440M [00:01<00:11, 34.5MB/s]
#
#
#
#
#
#
# rust_model.ot:   8% 41.9M/534M [00:01<00:12, 39.7MB/s]
# flax_model.msgpack:  17% 73.4M/438M [00:01<00:08, 44.3MB/s]
#
#
# model.safetensors:  17% 73.4M/440M [00:01<00:09, 39.2MB/s]
#
#
#
#
#
# tf_model.h5:   8% 41.9M/536M [00:01<00:15, 32.8MB/s]
#
#
#
#
# pytorch_model.bin:  12% 52.4M/440M [00:01<00:10, 38.5MB/s]
#
#
#
# model.onnx:  10% 52.4M/532M [00:01<00:13, 36.1MB/s]
#
# weight.bin:  16% 83.9M/532M [00:01<00:10, 41.5MB/s]
#
#
#
#
#
#
# rust_model.ot:  10% 52.4M/534M [00:01<00:13, 36.3MB/s]
# flax_model.msgpack:  19% 83.9M/438M [00:01<00:07, 44.3MB/s]
#
#
#
# model.onnx:  12% 62.9M/532M [00:01<00:11, 41.6MB/s]
#
#
# model.safetensors:  19% 83.9M/440M [00:01<00:09, 37.3MB/s]
#
#
#
#
#
# tf_model.h5:  10% 52.4M/536M [00:01<00:13, 35.5MB/s]
#
#
#
#
# pytorch_model.bin:  14% 62.9M/440M [00:01<00:10, 37.2MB/s]
#
# weight.bin:  18% 94.4M/532M [00:02<00:10, 42.7MB/s]
#
#
#
#
#
#
# rust_model.ot:  12% 62.9M/534M [00:01<00:11, 39.7MB/s]
#
#
#
# model.onnx:  14% 73.4M/532M [00:01<00:10, 45.6MB/s]
#
#
#
#
#
# tf_model.h5:  12% 62.9M/536M [00:01<00:11, 41.0MB/s]
# flax_model.msgpack:  22% 94.4M/438M [00:02<00:08, 41.8MB/s]
#
#
# model.safetensors:  21% 94.4M/440M [00:02<00:08, 38.6MB/s]
#
#
#
#
# pytorch_model.bin:  17% 73.4M/440M [00:02<00:09, 39.1MB/s]
#
#
#
# model.onnx:  16% 83.9M/532M [00:02<00:09, 46.5MB/s]
#
#
#
#
#
#
# rust_model.ot:  14% 73.4M/534M [00:02<00:11, 39.5MB/s]
#
# weight.bin:  20% 105M/532M [00:02<00:10, 39.6MB/s]
# flax_model.msgpack:  24% 105M/438M [00:02<00:07, 41.8MB/s]
#
#
#
#
# pytorch_model.bin:  19% 83.9M/440M [00:02<00:08, 43.8MB/s]
#
#
# model.safetensors:  24% 105M/440M [00:02<00:08, 39.6MB/s]
#
#
#
#
#
# tf_model.h5:  14% 73.4M/536M [00:02<00:13, 35.5MB/s]
#
#
#
#
#
#
# rust_model.ot:  16% 83.9M/534M [00:02<00:11, 40.3MB/s]
#
# weight.bin:  22% 115M/532M [00:02<00:10, 39.7MB/s]
#
#
#
# model.onnx:  18% 94.4M/532M [00:02<00:10, 41.4MB/s]
#
#
# model.safetensors:  26% 115M/440M [00:02<00:07, 42.4MB/s]
#
#
#
#
# pytorch_model.bin:  21% 94.4M/440M [00:02<00:07, 44.1MB/s]
# flax_model.msgpack:  26% 115M/438M [00:02<00:07, 41.2MB/s]
#
#
#
#
#
# tf_model.h5:  16% 83.9M/536M [00:02<00:11, 38.8MB/s]
#
# weight.bin:  24% 126M/532M [00:02<00:09, 42.3MB/s]
#
#
#
#
#
#
# rust_model.ot:  18% 94.4M/534M [00:02<00:11, 39.5MB/s]
# flax_model.msgpack:  29% 126M/438M [00:02<00:07, 43.2MB/s]
#
#
#
# model.onnx:  20% 105M/532M [00:02<00:10, 39.8MB/s]
#
#
# model.safetensors:  29% 126M/440M [00:02<00:07, 42.5MB/s]
#
#
#
#
# pytorch_model.bin:  24% 105M/440M [00:02<00:07, 43.9MB/s]
#
#
#
#
#
# tf_model.h5:  18% 94.4M/536M [00:02<00:10, 40.3MB/s]
#
# weight.bin:  26% 136M/532M [00:03<00:08, 45.1MB/s]
#
#
#
#
#
#
# rust_model.ot:  20% 105M/534M [00:02<00:10, 41.7MB/s]
# flax_model.msgpack:  31% 136M/438M [00:03<00:07, 41.8MB/s]
#
#
# model.safetensors:  31% 136M/440M [00:03<00:07, 41.4MB/s]
#
#
#
# model.onnx:  22% 115M/532M [00:03<00:10, 39.0MB/s]
#
#
#
#
# pytorch_model.bin:  26% 115M/440M [00:03<00:07, 40.9MB/s]
#
# weight.bin:  28% 147M/532M [00:03<00:08, 44.2MB/s]
#
#
#
#
#
# tf_model.h5:  20% 105M/536M [00:02<00:11, 36.8MB/s]
#
#
#
# model.onnx:  24% 126M/532M [00:03<00:09, 43.9MB/s]
#
#
#
#
#
#
# rust_model.ot:  22% 115M/534M [00:03<00:10, 39.0MB/s]
# flax_model.msgpack:  34% 147M/438M [00:03<00:07, 38.7MB/s]
#
#
#
#
# pytorch_model.bin:  29% 126M/440M [00:03<00:07, 40.2MB/s]
#
#
# model.safetensors:  33% 147M/440M [00:03<00:07, 37.9MB/s]
#
# weight.bin:  30% 157M/532M [00:03<00:08, 42.6MB/s]
#
#
#
#
#
# tf_model.h5:  22% 115M/536M [00:03<00:11, 38.0MB/s]
#
#
#
# model.onnx:  26% 136M/532M [00:03<00:08, 44.3MB/s]
#
#
#
#
#
#
# rust_model.ot:  24% 126M/534M [00:03<00:10, 38.4MB/s]
#
#
#
# model.onnx:  28% 147M/532M [00:05<00:28, 13.4MB/s]
#
#
# model.safetensors:  36% 157M/440M [00:05<00:22, 12.6MB/s]
# flax_model.msgpack:  36% 157M/438M [00:05<00:22, 12.5MB/s]
#
#
#
#
#
#
# rust_model.ot:  26% 136M/534M [00:05<00:30, 13.2MB/s]
#
#
#
#
#
# tf_model.h5:  23% 126M/536M [00:05<00:32, 12.7MB/s]
#
#
#
#
# pytorch_model.bin:  31% 136M/440M [00:05<00:24, 12.5MB/s]
#
# weight.bin:  32% 168M/532M [00:05<00:28, 12.9MB/s]
#
#
#
# model.onnx:  30% 157M/532M [00:05<00:21, 17.7MB/s]
#
#
#
#
# pytorch_model.bin:  33% 147M/440M [00:05<00:18, 16.0MB/s]
#
# weight.bin:  34% 178M/532M [00:05<00:21, 16.5MB/s]
#
#
#
#
#
#
# rust_model.ot:  27% 147M/534M [00:05<00:22, 16.9MB/s]
#
#
#
#
#
# tf_model.h5:  25% 136M/536M [00:05<00:24, 16.2MB/s]
# flax_model.msgpack:  38% 168M/438M [00:05<00:17, 15.8MB/s]
#
#
# model.safetensors:  38% 168M/440M [00:05<00:17, 15.6MB/s]
#
#
#
# model.onnx:  32% 168M/532M [00:05<00:17, 20.7MB/s]
#
# weight.bin:  35% 189M/532M [00:06<00:17, 19.9MB/s]
#
#
#
#
#
#
# rust_model.ot:  29% 157M/534M [00:05<00:18, 20.0MB/s]
#
#
#
#
#
# tf_model.h5:  27% 147M/536M [00:05<00:20, 19.3MB/s]
#
#
#
#
# pytorch_model.bin:  36% 157M/440M [00:06<00:14, 19.0MB/s]
# flax_model.msgpack:  41% 178M/438M [00:06<00:13, 18.8MB/s]
#
#
# model.safetensors:  40% 178M/440M [00:06<00:14, 18.2MB/s]
#
# weight.bin:  37% 199M/532M [00:06<00:13, 24.2MB/s]
#
#
#
# model.onnx:  34% 178M/532M [00:06<00:14, 23.7MB/s]
# flax_model.msgpack:  43% 189M/438M [00:06<00:10, 22.8MB/s]
#
#
#
#
#
#
# rust_model.ot:  31% 168M/534M [00:06<00:15, 23.4MB/s]
#
#
# model.safetensors:  43% 189M/440M [00:06<00:11, 22.6MB/s]
#
#
#
#
#
# tf_model.h5:  29% 157M/536M [00:06<00:16, 22.3MB/s]
#
#
#
#
# pytorch_model.bin:  38% 168M/440M [00:06<00:12, 22.3MB/s]
#
# weight.bin:  39% 210M/532M [00:06<00:11, 28.4MB/s]
#
#
#
# model.onnx:  35% 189M/532M [00:06<00:12, 27.6MB/s]
# flax_model.msgpack:  45% 199M/438M [00:06<00:08, 26.9MB/s]
#
#
#
#
#
# tf_model.h5:  31% 168M/536M [00:06<00:14, 26.3MB/s]
#
#
#
#
# pytorch_model.bin:  40% 178M/440M [00:06<00:10, 25.6MB/s]
#
#
#
#
#
#
# rust_model.ot:  33% 178M/534M [00:06<00:13, 26.0MB/s]
#
#
# model.safetensors:  45% 199M/440M [00:06<00:09, 25.0MB/s]
#
# weight.bin:  41% 220M/532M [00:06<00:09, 32.6MB/s]
#
#
#
# model.onnx:  37% 199M/532M [00:06<00:10, 30.6MB/s]
# flax_model.msgpack:  48% 210M/438M [00:06<00:07, 29.1MB/s]
#
#
#
#
#
# tf_model.h5:  33% 178M/536M [00:06<00:11, 30.0MB/s]
#
#
# model.safetensors:  48% 210M/440M [00:07<00:08, 28.3MB/s]
#
# weight.bin:  43% 231M/532M [00:07<00:08, 34.1MB/s]
#
#
#
#
# pytorch_model.bin:  43% 189M/440M [00:06<00:09, 26.9MB/s]
#
#
#
#
#
#
# rust_model.ot:  35% 189M/534M [00:06<00:13, 25.8MB/s]
#
#
#
# model.onnx:  39% 210M/532M [00:07<00:11, 28.7MB/s]
# flax_model.msgpack:  50% 220M/438M [00:07<00:07, 29.1MB/s]
#
#
#
#
#
# tf_model.h5:  35% 189M/536M [00:07<00:12, 28.8MB/s]
#
#
#
#
#
#
# rust_model.ot:  37% 199M/534M [00:07<00:11, 29.1MB/s]
#
#
# model.safetensors:  50% 220M/440M [00:07<00:07, 28.5MB/s]
#
#
#
#
# pytorch_model.bin:  45% 199M/440M [00:07<00:08, 28.0MB/s]
#
# weight.bin:  45% 241M/532M [00:07<00:09, 31.3MB/s]
#
#
#
# model.onnx:  41% 220M/532M [00:07<00:10, 29.8MB/s]
# flax_model.msgpack:  53% 231M/438M [00:07<00:06, 30.5MB/s]
#
#
#
#
#
#
# rust_model.ot:  39% 210M/534M [00:07<00:10, 32.1MB/s]
#
#
#
#
#
# tf_model.h5:  37% 199M/536M [00:07<00:11, 28.3MB/s]
#
#
# model.safetensors:  52% 231M/440M [00:07<00:07, 29.5MB/s]
#
# weight.bin:  47% 252M/532M [00:07<00:08, 31.3MB/s]
#
#
#
#
# pytorch_model.bin:  48% 210M/440M [00:07<00:08, 27.5MB/s]
# flax_model.msgpack:  55% 241M/438M [00:07<00:05, 34.1MB/s]
#
#
#
#
#
#
# rust_model.ot:  41% 220M/534M [00:07<00:08, 36.1MB/s]
#
#
#
# model.onnx:  43% 231M/532M [00:07<00:10, 28.2MB/s]
#
#
#
#
#
# tf_model.h5:  39% 210M/536M [00:07<00:10, 30.1MB/s]
#
#
# model.safetensors:  55% 241M/440M [00:08<00:06, 30.2MB/s]
# flax_model.msgpack:  57% 252M/438M [00:08<00:05, 35.8MB/s]
#
# weight.bin:  49% 262M/532M [00:08<00:08, 33.1MB/s]
#
#
#
#
# pytorch_model.bin:  50% 220M/440M [00:07<00:07, 28.3MB/s]
#
#
#
#
#
#
# rust_model.ot:  43% 231M/534M [00:07<00:08, 35.7MB/s]
#
#
#
# model.onnx:  45% 241M/532M [00:08<00:09, 29.6MB/s]
#
#
#
#
#
# tf_model.h5:  41% 220M/536M [00:08<00:10, 30.8MB/s]
#
#
# model.safetensors:  57% 252M/440M [00:08<00:06, 30.5MB/s]
#
# weight.bin:  51% 273M/532M [00:08<00:08, 31.7MB/s]
#
#
#
#
# pytorch_model.bin:  52% 231M/440M [00:08<00:07, 29.8MB/s]
# flax_model.msgpack:  60% 262M/438M [00:08<00:05, 32.1MB/s]
#
#
#
#
#
#
# rust_model.ot:  45% 241M/534M [00:08<00:08, 34.3MB/s]
#
#
#
# model.onnx:  47% 252M/532M [00:08<00:09, 31.0MB/s]
#
#
#
#
#
# tf_model.h5:  43% 231M/536M [00:08<00:09, 31.4MB/s]
#
# weight.bin:  53% 283M/532M [00:08<00:07, 34.5MB/s]
#
#
# model.safetensors:  60% 262M/440M [00:08<00:05, 31.7MB/s]
# flax_model.msgpack:  62% 273M/438M [00:08<00:04, 33.6MB/s]
#
#
#
#
# pytorch_model.bin:  55% 241M/440M [00:08<00:06, 30.6MB/s]
#
#
#
#
#
#
# rust_model.ot:  47% 252M/534M [00:08<00:08, 35.2MB/s]
#
#
#
# model.onnx:  49% 262M/532M [00:08<00:08, 30.5MB/s]
#
#
#
#
#
# tf_model.h5:  45% 241M/536M [00:08<00:09, 31.4MB/s]
#
# weight.bin:  55% 294M/532M [00:09<00:07, 33.4MB/s]
#
#
# model.safetensors:  62% 273M/440M [00:09<00:05, 30.5MB/s]
#
#
#
#
# pytorch_model.bin:  57% 252M/440M [00:08<00:06, 31.2MB/s]
# flax_model.msgpack:  65% 283M/438M [00:09<00:04, 31.9MB/s]
#
#
#
#
#
#
# rust_model.ot:  49% 262M/534M [00:08<00:08, 32.8MB/s]
#
#
#
#
#
# tf_model.h5:  47% 252M/536M [00:08<00:08, 33.8MB/s]
#
#
#
# model.onnx:  51% 273M/532M [00:09<00:08, 31.8MB/s]
#
# weight.bin:  57% 304M/532M [00:09<00:07, 32.2MB/s]
#
#
# model.safetensors:  64% 283M/440M [00:09<00:05, 29.7MB/s]
# flax_model.msgpack:  67% 294M/438M [00:09<00:04, 31.8MB/s]
#
#
#
#
# pytorch_model.bin:  60% 262M/440M [00:09<00:06, 28.3MB/s]
#
#
#
#
#
#
# rust_model.ot:  51% 273M/534M [00:09<00:08, 29.8MB/s]
#
# weight.bin:  59% 315M/532M [00:09<00:06, 34.1MB/s]
#
#
#
#
#
# tf_model.h5:  49% 262M/536M [00:09<00:08, 30.9MB/s]
#
#
#
# model.onnx:  53% 283M/532M [00:09<00:08, 30.4MB/s]
#
#
# model.safetensors:  67% 294M/440M [00:09<00:04, 32.4MB/s]
# flax_model.msgpack:  69% 304M/438M [00:09<00:03, 33.5MB/s]
#
#
#
#
#
#
# rust_model.ot:  53% 283M/534M [00:09<00:07, 33.0MB/s]
#
#
#
# model.onnx:  55% 294M/532M [00:09<00:06, 35.6MB/s]
#
# weight.bin:  61% 325M/532M [00:09<00:05, 37.2MB/s]
#
#
#
#
# pytorch_model.bin:  62% 273M/440M [00:09<00:05, 29.6MB/s]
#
#
#
#
#
# tf_model.h5:  51% 273M/536M [00:09<00:07, 33.6MB/s]
# flax_model.msgpack:  72% 315M/438M [00:09<00:03, 37.3MB/s]
#
#
# model.safetensors:  69% 304M/440M [00:10<00:04, 33.7MB/s]
#
#
#
#
#
#
# rust_model.ot:  55% 294M/534M [00:09<00:06, 35.0MB/s]
#
#
#
# model.onnx:  57% 304M/532M [00:10<00:06, 34.7MB/s]
#
#
#
#
#
# tf_model.h5:  53% 283M/536M [00:09<00:07, 32.5MB/s]
#
#
#
#
# pytorch_model.bin:  64% 283M/440M [00:10<00:05, 28.7MB/s]
#
#
#
#
#
#
# rust_model.ot:  57% 304M/534M [00:10<00:06, 35.3MB/s]
#
#
#
#
# pytorch_model.bin:  67% 294M/440M [00:10<00:04, 34.5MB/s]
#
# weight.bin:  63% 336M/532M [00:10<00:06, 28.5MB/s]
#
#
#
#
#
# tf_model.h5:  55% 294M/536M [00:10<00:06, 37.5MB/s]
# flax_model.msgpack:  74% 325M/438M [00:10<00:03, 29.0MB/s]
#
#
# model.safetensors:  71% 315M/440M [00:10<00:04, 27.5MB/s]
#
#
#
#
#
#
# rust_model.ot:  59% 315M/534M [00:10<00:05, 39.8MB/s]
#
#
#
# model.onnx:  59% 315M/532M [00:10<00:07, 30.0MB/s]
#
# weight.bin:  65% 346M/532M [00:10<00:06, 30.6MB/s]
#
#
#
#
#
# tf_model.h5:  57% 304M/536M [00:10<00:06, 34.9MB/s]
# flax_model.msgpack:  77% 336M/438M [00:10<00:03, 29.9MB/s]
#
#
# model.safetensors:  74% 325M/440M [00:10<00:03, 29.0MB/s]
#
#
#
#
# pytorch_model.bin:  69% 304M/440M [00:10<00:04, 31.1MB/s]
#
#
#
#
#
#
# rust_model.ot:  61% 325M/534M [00:10<00:05, 37.6MB/s]
#
#
#
# model.onnx:  61% 325M/532M [00:10<00:06, 31.4MB/s]
#
# weight.bin:  67% 357M/532M [00:11<00:05, 31.3MB/s]
#
#
# model.safetensors:  76% 336M/440M [00:11<00:03, 30.4MB/s]
#
#
#
#
#
# tf_model.h5:  59% 315M/536M [00:10<00:06, 32.7MB/s]
# flax_model.msgpack:  79% 346M/438M [00:11<00:03, 30.1MB/s]
#
#
#
#
# pytorch_model.bin:  71% 315M/440M [00:11<00:04, 30.1MB/s]
#
#
#
# model.onnx:  63% 336M/532M [00:11<00:05, 33.0MB/s]
#
# weight.bin:  69% 367M/532M [00:11<00:04, 35.2MB/s]
#
#
#
#
#
#
# rust_model.ot:  63% 336M/534M [00:10<00:05, 33.4MB/s]
#
#
# model.safetensors:  79% 346M/440M [00:11<00:02, 31.6MB/s]
#
#
#
#
#
# tf_model.h5:  61% 325M/536M [00:11<00:06, 32.5MB/s]
#
#
#
#
# pytorch_model.bin:  74% 325M/440M [00:11<00:03, 31.3MB/s]
# flax_model.msgpack:  81% 357M/438M [00:11<00:02, 29.4MB/s]
#
#
#
# model.onnx:  65% 346M/532M [00:11<00:06, 30.7MB/s]
#
# weight.bin:  71% 377M/532M [00:11<00:04, 32.9MB/s]
#
#
#
#
#
#
# rust_model.ot:  65% 346M/534M [00:11<00:05, 31.9MB/s]
#
#
# model.safetensors:  81% 357M/440M [00:11<00:02, 35.6MB/s]
#
#
#
#
#
# tf_model.h5:  63% 336M/536M [00:11<00:06, 33.3MB/s]
#
#
#
#
# pytorch_model.bin:  76% 336M/440M [00:11<00:03, 32.3MB/s]
# flax_model.msgpack:  84% 367M/438M [00:11<00:02, 31.0MB/s]
#
# weight.bin:  73% 388M/532M [00:11<00:04, 34.4MB/s]
#
#
#
# model.onnx:  67% 357M/532M [00:11<00:05, 32.3MB/s]
#
#
# model.safetensors:  83% 367M/440M [00:12<00:02, 34.1MB/s]
#
#
#
#
#
#
# rust_model.ot:  67% 357M/534M [00:11<00:05, 30.3MB/s]
#
#
#
#
# pytorch_model.bin:  79% 346M/440M [00:11<00:02, 33.7MB/s]
#
# weight.bin:  75% 398M/532M [00:12<00:03, 37.3MB/s]
#
#
#
#
#
# tf_model.h5:  65% 346M/536M [00:11<00:05, 32.3MB/s]
#
#
#
# model.onnx:  69% 367M/532M [00:12<00:04, 34.5MB/s]
# flax_model.msgpack:  86% 377M/438M [00:12<00:01, 31.9MB/s]
#
#
# model.safetensors:  86% 377M/440M [00:12<00:01, 38.2MB/s]
#
#
#
#
#
#
# rust_model.ot:  69% 367M/534M [00:12<00:05, 32.1MB/s]
#
# weight.bin:  77% 409M/532M [00:12<00:03, 35.6MB/s]
#
#
# model.safetensors:  88% 388M/440M [00:12<00:01, 39.4MB/s]
#
#
#
#
# pytorch_model.bin:  81% 357M/440M [00:12<00:02, 31.6MB/s]
#
#
#
#
#
# tf_model.h5:  67% 357M/536M [00:12<00:05, 30.0MB/s]
#
#
#
# model.onnx:  71% 377M/532M [00:12<00:04, 31.3MB/s]
# flax_model.msgpack:  89% 388M/438M [00:12<00:01, 30.0MB/s]
#
#
#
#
#
#
# rust_model.ot:  71% 377M/534M [00:12<00:04, 32.6MB/s]
#
# weight.bin:  79% 419M/532M [00:12<00:03, 34.2MB/s]
#
#
# model.safetensors:  90% 398M/440M [00:12<00:01, 36.6MB/s]
#
#
#
#
# pytorch_model.bin:  83% 367M/440M [00:12<00:02, 31.6MB/s]
# flax_model.msgpack:  91% 398M/438M [00:12<00:01, 31.5MB/s]
#
#
#
#
#
#
# rust_model.ot:  73% 388M/534M [00:12<00:04, 34.3MB/s]
#
#
#
#
#
# tf_model.h5:  68% 367M/536M [00:12<00:05, 30.4MB/s]
#
#
#
# model.onnx:  73% 388M/532M [00:12<00:04, 31.3MB/s]
#
# weight.bin:  81% 430M/532M [00:12<00:02, 37.9MB/s]
#
#
#
#
# pytorch_model.bin:  86% 377M/440M [00:12<00:01, 35.3MB/s]
#
#
# model.safetensors:  93% 409M/440M [00:13<00:00, 35.4MB/s]
# flax_model.msgpack:  93% 409M/438M [00:13<00:00, 33.8MB/s]
#
#
#
#
#
# tf_model.h5:  70% 377M/536M [00:12<00:04, 32.9MB/s]
#
#
#
#
#
#
# rust_model.ot:  75% 398M/534M [00:12<00:04, 33.8MB/s]
#
#
#
# model.onnx:  75% 398M/532M [00:13<00:04, 31.8MB/s]
#
#
#
#
# pytorch_model.bin:  88% 388M/440M [00:13<00:01, 38.1MB/s]
#
# weight.bin:  83% 440M/532M [00:13<00:02, 37.7MB/s]
# flax_model.msgpack:  96% 419M/438M [00:13<00:00, 36.7MB/s]
#
#
# model.safetensors:  95% 419M/440M [00:13<00:00, 37.1MB/s]
#
#
#
#
#
# tf_model.h5:  72% 388M/536M [00:13<00:04, 34.7MB/s]
#
#
#
# model.onnx:  77% 409M/532M [00:13<00:03, 33.6MB/s]
#
# weight.bin:  85% 451M/532M [00:13<00:02, 39.8MB/s]
# flax_model.msgpack:  98% 430M/438M [00:13<00:00, 41.9MB/s]
#
#
#
#
#
#
# rust_model.ot:  77% 409M/534M [00:13<00:03, 32.7MB/s]
#
#
#
#
# pytorch_model.bin:  90% 398M/440M [00:13<00:01, 37.5MB/s]
#
#
#
#
#
# tf_model.h5:  74% 398M/536M [00:13<00:03, 38.1MB/s]
#
#
# model.safetensors:  98% 430M/440M [00:13<00:00, 35.1MB/s]
# flax_model.msgpack: 100% 438M/438M [00:13<00:00, 39.9MB/s]
#
#
#
# model.onnx:  79% 419M/532M [00:13<00:03, 34.1MB/s]
#
# flax_model.msgpack: 100% 438M/438M [00:13<00:00, 31.5MB/s]
#
#
#
#
#
# pytorch_model.bin:  93% 409M/440M [00:13<00:00, 35.9MB/s]Download complete. Moving file to /content/hf/misc/hub/models--bert-base-uncased/blobs/ea201fabe466ef7182f1f687fb5be4b62a73d3a78883f11264ff7f682cdb54bf
#
#
#
#
#
#
#
# rust_model.ot:  79% 419M/534M [00:13<00:03, 31.4MB/s]
#
#
#
#
#
# tf_model.h5:  76% 409M/536M [00:13<00:03, 35.6MB/s]
#
#
# model.safetensors: 100% 440M/440M [00:14<00:00, 34.3MB/s]
#
#
#
# model.onnx:  81% 430M/532M [00:13<00:02, 34.8MB/s]
#
# model.safetensors: 100% 440M/440M [00:14<00:00, 31.2MB/s]
# Download complete. Moving file to /content/hf/misc/hub/models--bert-base-uncased/blobs/68d45e234eb4a928074dfd868cead0219ab85354cc53d20e772753c6bb9169d3
#
#
#
#
#
# pytorch_model.bin:  95% 419M/440M [00:13<00:00, 37.8MB/s]
#
#
#
#
#
#
# rust_model.ot:  80% 430M/534M [00:13<00:03, 31.6MB/s]
#
#
#
#
#
# tf_model.h5:  78% 419M/536M [00:15<00:07, 15.1MB/s]
#
#
#
# model.onnx:  83% 440M/532M [00:15<00:06, 14.6MB/s]
#
# weight.bin:  91% 482M/532M [00:15<00:03, 14.1MB/s]
#
#
#
#
# pytorch_model.bin:  98% 430M/440M [00:15<00:00, 14.3MB/s]
#
#
#
#
#
#
# rust_model.ot:  82% 440M/534M [00:15<00:06, 13.7MB/s]
#
#
#
#
#
# tf_model.h5:  80% 430M/536M [00:15<00:06, 16.0MB/s]
#
#
#
#
# pytorch_model.bin: 100% 440M/440M [00:15<00:00, 17.7MB/s]
#
# weight.bin:  93% 493M/532M [00:16<00:02, 17.3MB/s]
#
#
#
# pytorch_model.bin: 100% 440M/440M [00:16<00:00, 27.5MB/s]
# Download complete. Moving file to /content/hf/misc/hub/models--bert-base-uncased/blobs/097417381d6c7230bd9e3557456d726de6e83245ec8b24f529f60198a67b203a
#
#
#
#
#
#
#
# rust_model.ot:  84% 451M/534M [00:15<00:04, 17.0MB/s]
#
#
#
#
#
# tf_model.h5:  82% 440M/536M [00:15<00:04, 20.4MB/s]
#
#
#
# model.onnx:  87% 461M/532M [00:16<00:03, 21.1MB/s]
#
# weight.bin:  95% 503M/532M [00:16<00:01, 21.9MB/s]
#
#
#
#
#
#
# rust_model.ot:  86% 461M/534M [00:16<00:03, 22.0MB/s]
#
#
#
#
#
# tf_model.h5:  84% 451M/536M [00:16<00:03, 26.1MB/s]
#
#
#
#
#
#
# rust_model.ot:  88% 472M/534M [00:16<00:02, 27.8MB/s]
#
# weight.bin:  97% 514M/532M [00:16<00:00, 25.8MB/s]
#
#
#
#
#
# tf_model.h5:  86% 461M/536M [00:16<00:02, 32.1MB/s]
#
#
#
# model.onnx:  89% 472M/532M [00:16<00:02, 24.6MB/s]
#
#
#
#
#
#
# rust_model.ot:  90% 482M/534M [00:16<00:01, 35.3MB/s]
#
# weight.bin:  99% 524M/532M [00:16<00:00, 32.8MB/s]
#
#
#
# model.onnx:  91% 482M/532M [00:16<00:01, 31.0MB/s]
#
#
#
#
#
# tf_model.h5:  88% 472M/536M [00:16<00:01, 38.1MB/s]
#
#
#
#
#
#
# rust_model.ot:  92% 493M/534M [00:16<00:00, 43.5MB/s]
#
# weight.bin: 100% 532M/532M [00:16<00:00, 31.4MB/s]
#
#
#
#
#
#
# tf_model.h5:  90% 482M/536M [00:16<00:01, 44.2MB/s]Download complete. Moving file to /content/hf/misc/hub/models--bert-base-uncased/blobs/c0c9f4914b4f0053785e96b8583cd59cda63c2f1b6e95a03970d772bf097e289
#
#
#
#
#
#
#
# rust_model.ot:  94% 503M/534M [00:16<00:00, 50.8MB/s]
#
#
#
# Fetching 16 files:  38% 6/16 [00:17<00:31,  3.12s/it]
#
#
#
#
#
# tf_model.h5:  92% 493M/536M [00:16<00:00, 50.6MB/s]
#
#
#
# model.onnx:  95% 503M/532M [00:16<00:00, 43.2MB/s]
#
#
#
#
#
#
# rust_model.ot:  96% 514M/534M [00:16<00:00, 52.7MB/s]
#
#
#
# model.onnx:  97% 514M/532M [00:17<00:00, 49.8MB/s]
#
#
#
#
#
#
# rust_model.ot:  98% 524M/534M [00:17<00:00, 53.1MB/s]
#
#
#
# model.onnx:  99% 524M/532M [00:17<00:00, 58.0MB/s]
#
#
#
#
#
# tf_model.h5:  94% 503M/536M [00:16<00:00, 45.8MB/s]
#
#
#
#
#
#
# rust_model.ot: 100% 534M/534M [00:17<00:00, 58.7MB/s]
#
#
#
#
#
# model.onnx: 100% 532M/532M [00:19<00:00, 27.7MB/s]
# Download complete. Moving file to /content/hf/misc/hub/models--bert-base-uncased/blobs/44d7a2896d341c51fb1eba89aea3a590e6af0ce33e25481136f7eeecb62e5f7f
# rust_model.ot: 100% 534M/534M [00:21<00:00, 25.2MB/s]
# Download complete. Moving file to /content/hf/misc/hub/models--bert-base-uncased/blobs/afd9aa425fd45c5655d3d43a0d041f9b76729bf475d6c017a0e9304a38f89972
# Fetching 16 files:  75% 12/16 [00:22<00:06,  1.58s/it]
#
#
#
#
#
# tf_model.h5:  98% 524M/536M [00:21<00:01, 7.25MB/s]
#
#
#
#
#
# tf_model.h5: 100% 536M/536M [00:21<00:00, 24.8MB/s]
# Download complete. Moving file to /content/hf/misc/hub/models--bert-base-uncased/blobs/a7a17d6d844b5de815ccab5f42cad6d24496db3850a2a43d8258221018ce87d2
# Fetching 16 files: 100% 16/16 [00:23<00:00,  1.44s/it]
# /content/hf/misc/hub/models--bert-base-uncased/snapshots/86b5e0934494bd15c9632b12f734a8a67f723594
