# %% [markdown]
# <a href="https://colab.research.google.com/github/harnalashok/LLMs/blob/main/Gen_AI_and_LLMs_using_KNIME.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Last amended: 26th March, 2024

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('PGzzgYGnnlM')

# %% [markdown]
# Good References:
#
# 1. Build a custom AI-powered data app with KNIME Link [here](https://www.knime.com/blog/build-a-custom-AI-powered-data-app)
# 2. Data App Chat Bot on Custom Knowledge Base by Paolo Link [here](https://hub.knime.com/paolotamag/spaces/Public/Data%20App%20Chat%20Bot%20on%20Custom%20Knowledge%20Base~fWSj6BG3JS2adf1x/current-state)
# 3.  AI Extension Example Workflows Link [here](https://hub.knime.com/knime/spaces/AI%20Extension%20Example%20Workflows/~CzxTTU_Gi4moY5Gz/)
# 4. FAISS Vector Store Creator and workflows Link [here](https://hub.knime.com/knime/extensions/org.knime.python.features.llm/latest/org.knime.python3.nodes.extension.ExtensionNodeSetFactory$DynamicExtensionNodeFactory:e1168c28)
# 5. Huggingface related workflows Link [here](https://hub.knime.com/knime/extensions/org.knime.python.features.llm/latest/org.knime.python3.nodes.extension.ExtensionNodeSetFactory$DynamicExtensionNodeFactory:3b23734)
# 6. word2vec based workflows Link [here](https://hub.knime.com/knime/extensions/org.knime.features.ext.textprocessing.dl4j/latest/org.knime.ext.textprocessing.dl4j.nodes.embeddings.learn.w2v.Word2VecLearnerNodeFactory)

# %%
################
