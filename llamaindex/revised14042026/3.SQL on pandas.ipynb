# %% [markdown]
# ## Pandas natural lang query

# %%
# 14th August, 2026
# Natural language query on  pandas Dataframe
# Ref: https://developers.llamaindex.ai/python/examples/query_engine/pandas_query_engine/
# CSV files: https://github.com/datablist/sample-csv-files

# %%
#1.0 Call libraries
#    Requires: 
#      pip install llama-index llama-index-experimental pandas

from llama_index.embeddings.ollama import OllamaEmbedding
from llama_index.llms.ollama import Ollama

# File/dir readers
from llama_index.core import SimpleDirectoryReader

# PandasQueryEngine is a tool within the LlamaIndex framework 
# that lets you query a Pandas DataFrame using natural language
from llama_index.experimental.query_engine import PandasQueryEngine

# Global variables
from llama_index.core import Settings
import pandas as pd

# %%
# 1.01
# Requires 'ollama sigin' on ubuntu. AND 'Connect Device'
# Then go to the browser, siginin and get API key.
import os
OLLAMA_API_KEY="259fb45e24d94732b83da31232b87ecd.VK3OpZmr0KbCwq4kHCMlWTk-"
api_key = os.getenv("OLLAMA_API_KEY")

# %%
# 1.1 Initialise llms
#     lightweight Cloud models that work well for this task are: 
#        "minimax-m3:cloud" , # "gpt-oss:20b-cloud" , #  "nemotron-3-nano:30b-cloud",
#         "gemma4:cloud" 
# No need to execute 'ollama run command'

llm = Ollama(
             model= "minimax-m3:cloud" ,  # "deepseek-r1:7b" "qwen3.5:4b",  "llama3.2:latest",
             request_timeout=3600,        # Change it
             temperature = 0,             # To produce stable deterministic output
             #context_window=,            # Limit timeouts
             mirostat = 0
             )

embed_model = OllamaEmbedding(
                                model_name="nomic-embed-text",      # Using foundational model may be overkill
                                base_url="http://localhost:11434",
                              )

# %%
# 1.02 Check if the API key is set correctly
#      ANd cloud model is available
llm.complete("What is the capital of France?")
# Out:
# CompletionResponse(text='The capital of France is **Paris**.', additional_kwargs={}, raw={'model': 'minimax-m3', 'created_at': '2026-08-14T10:06:51.733691041Z', 'done': True, 'done_reason': 'stop', 'total_duration': 1883557039, 'load_duration': None, 'prompt_eval_count': 183, 'prompt_eval_duration': None, 'eval_count': 24, 'eval_duration': None, 'message': Message(role='assistant', content='The capital of France is **Paris**.', thinking='The user is asking a straightforward factual question about the capital of France.\n', images=None, tool_name=None, tool_calls=None), 'logprobs': None, 'usage': {'prompt_tokens': 183, 'completion_tokens': 24, 'total_tokens': 207}}, logprobs=None, delta=None)

# %%
# 1.1 Initialise llms
#     lightweight Cloud models that work well for this task are: 
#        "minimax-m3:cloud" , # "gpt-oss:20b-cloud" , #  "nemotron-3-nano:30b-cloud",
#         "gemma4:cloud" 
# No need to execute 'ollama run command'

llm = Ollama(
             model= "minimax-m3:cloud" ,  # "deepseek-r1:7b" "qwen3.5:4b",  "llama3.2:latest",
             request_timeout=3600,        # Change it
             temperature = 0,             # To produce stable deterministic output
             #context_window=,            # Limit timeouts
             mirostat = 0
             )

embed_model = OllamaEmbedding(
                                model_name="nomic-embed-text",      # Using foundational model may be overkill
                                base_url="http://localhost:11434",
                              )

# %%
llm.complete("What is the capital of France?")
# Out:
# CompletionResponse(text='The capital of France is **Paris**.', additional_kwargs={}, raw={'model': 'minimax-m3', 'created_at': '2026-08-14T10:07:09.615653689Z', 'done': True, 'done_reason': 'stop', 'total_duration': 1517214920, 'load_duration': None, 'prompt_eval_count': 183, 'prompt_eval_duration': None, 'eval_count': 55, 'eval_duration': None, 'message': Message(role='assistant', content='The capital of France is **Paris**.', thinking='The user is asking a straightforward question: "What is the capital of France?" This is a simple factual question with a clear answer. Paris is the capital of France. I should respond directly and clearly, without unnecessary elaboration.\n', images=None, tool_name=None, tool_calls=None), 'logprobs': None, 'usage': {'prompt_tokens': 183, 'completion_tokens': 55, 'total_tokens': 238}}, logprobs=None, delta=None)

# %%
# 1.2 Read csv file
df = pd.read_csv("/home/ashok/lprojects/customers-100.csv")

# 1.3
df.columns
df.head()
df.shape
# Out:
# (100, 12)

# %%
# 2. Initialize the query engine
# Setting verbose=True lets you see the generated pandas code
query_engine = PandasQueryEngine(df=df, 
                                 llm = llm, 
                                 verbose=True,             # see the generated pandas code
                                 synthesize_response=True  # Synthesizes Response: Puts the output in natural language
                                )

# %%
# 3. Query the data in natural language   Aaronstad
# response = query_engine.query("Give me the 'FirstName' of all those who are in City of 'East Leonard'")
response = query_engine.query("Give me the 'FirstName' of all those who are in City of 'Isabelborough'")
print(response)
# Out:
# > Pandas Instructions:
# ```
# df[df['City'] == 'Isabelborough']['First Name']
# ```
# > Pandas Output: 2    Roy
# Name: First Name, dtype: object
# Roy

# %%
###################
