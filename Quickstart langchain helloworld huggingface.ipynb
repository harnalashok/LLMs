# %% [markdown]
# <a href="https://colab.research.google.com/github/harnalashok/LLMs/blob/main/Quickstart%20langchain%20helloworld%20huggingface.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Last amended: 6th June, 2024
# Using Huggingface pipeline
# Text Sumarization, Text Generation

# Execute in colab with T4 GPU

# %%
# 1.0 Install needed software
! pip install langchain_community --quiet
! pip install transformers --quiet
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 35.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 973.6/973.6 kB 45.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 310.4/310.4 kB 32.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.8/124.8 kB 16.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.2/49.2 kB 5.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 8.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 142.5/142.5 kB 19.7 MB/s eta 0:00:00

# %% [markdown]
# [Huggingfacepipeline](https://api.python.langchain.com/en/latest/llms/langchain_community.llms.huggingface_pipeline.HuggingFacePipeline.html)
# [Hugging Face Local Pipelines examples](https://python.langchain.com/v0.1/docs/integrations/llms/huggingface_pipelines/)

# %%
# 1.0.1 Call HuggingFacePipeline
from langchain_community.llms.huggingface_pipeline import HuggingFacePipeline

# %% [markdown]
# ## Text summarization
#
# >For text summarization, models available on huggingface are [here](https://huggingface.co/models?pipeline_tag=summarization).
#
# >[Source code](https://api.python.langchain.com/en/latest/_modules/langchain_community/llms/huggingface_pipeline.html#HuggingFacePipeline.from_model_id) of `from_model_id()` method is quite educative in the sense what all it imports and what all it does.

# %%
# 1.0.2 Load requisite hf model
#       Models can be loaded by specifying the model_id, task for which loaded
#       and number of tokens to generate
#       Use from_model_id method()

hf = HuggingFacePipeline.from_model_id(
                                      model_id="facebook/bart-large-cnn",  # 1.63gb
                                      task="summarization",
                                      pipeline_kwargs={"max_new_tokens": 30},
                                      )
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# config.json:   0%|          | 0.00/1.58k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.63G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# WARNING:langchain_community.llms.huggingface_pipeline:Device has 1 GPUs available. Provide device={deviceId} to `from_model_id` to use availableGPUs for execution. deviceId is -1 (default) for CPU and can be a positive integer associated with CUDA device id.

# %%
# 1.0.3
ARTICLE = """ New York (CNN)When Liana Barrientos was 23 years old, she got married in Westchester County, New York.
A year later, she got married again in Westchester County, but to a different man and without divorcing her first husband.
Only 18 days after that marriage, she got hitched yet again. Then, Barrientos declared "I do" five more times, sometimes only within two weeks of each other.
In 2010, she married once more, this time in the Bronx. In an application for a marriage license, she stated it was her "first and only" marriage.
Barrientos, now 39, is facing two criminal counts of "offering a false instrument for filing in the first degree," referring to her false statements on the
2010 marriage license application, according to court documents.
Prosecutors said the marriages were part of an immigration scam.
On Friday, she pleaded not guilty at State Supreme Court in the Bronx, according to her attorney, Christopher Wright, who declined to comment further.
After leaving court, Barrientos was arrested and charged with theft of service and criminal trespass for allegedly sneaking into the New York subway through an emergency exit, said Detective
Annette Markowski, a police spokeswoman. In total, Barrientos has been married 10 times, with nine of her marriages occurring between 1999 and 2002.
All occurred either in Westchester County, Long Island, New Jersey or the Bronx. She is believed to still be married to four men, and at one time, she was married to eight men at once, prosecutors say.
Prosecutors said the immigration scam involved some of her husbands, who filed for permanent residence status shortly after the marriages.
Any divorces happened only after such filings were approved. It was unclear whether any of the men will be prosecuted.
The case was referred to the Bronx District Attorney\'s Office by Immigration and Customs Enforcement and the Department of Homeland Security\'s
Investigation Division. Seven of the men are from so-called "red-flagged" countries, including Egypt, Turkey, Georgia, Pakistan and Mali.
Her eighth husband, Rashid Rajput, was deported in 2006 to his native Pakistan after an investigation by the Joint Terrorism Task Force.
If convicted, Barrientos faces up to four years in prison.  Her next court appearance is scheduled for May 18.
"""

# %%
# %%time

# 1.0.4 Summarise now
hf(ARTICLE)
# Out:
# /usr/local/lib/python3.10/dist-packages/langchain_core/_api/deprecation.py:119: LangChainDeprecationWarning: The method `BaseLLM.__call__` was deprecated in langchain-core 0.1.7 and will be removed in 0.3.0. Use invoke instead.
#   warn_deprecated(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1192: UserWarning: Unfeasible length constraints: `min_length` (56) is larger than the maximum possible length (31). Generation will stop at the defined maximum length. You should decrease the minimum length and/or increase the maximum length. Note that `max_length` is set to 31, its default value.
#   warnings.warn(
# CPU times: user 10.5 s, sys: 404 ms, total: 10.9 s
# Wall time: 11.9 s
# 'Liana Barrientos, 39, is charged with two counts of "offering a false instrument for filing in the first degree" She'

# %%
# 2.0 Alternatively, you can pass the document as a prompttemplate:

from langchain_core.prompts import PromptTemplate

# %%
# 2.0.1
template = ARTICLE
prompt = PromptTemplate.from_template(template)

# %%
# 2.0.2 Pipe prompt into hf:
chain = prompt | hf

# %%
# %%time

# 2.0.3 Invoke chain. There are no variables:
chain.invoke(input = {})
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1192: UserWarning: Unfeasible length constraints: `min_length` (56) is larger than the maximum possible length (31). Generation will stop at the defined maximum length. You should decrease the minimum length and/or increase the maximum length. Note that `max_length` is set to 31, its default value.
#   warnings.warn(
# CPU times: user 9.4 s, sys: 266 ms, total: 9.67 s
# Wall time: 9.8 s
# 'Liana Barrientos, 39, is charged with two counts of "offering a false instrument for filing in the first degree" She'

# %% [markdown]
# ## Text generation
# Small models are to be searched that occupy less RAM. Else they will not fit into RAM available in Colab.
# `gpt2` is one such model.

# %%
# 3.0 Some models need it some do not.
#     Depends from model to model:
! pip install tiktoken --quiet

# %%
# 3.0.1 Load requisite hf model
#       Models can be loaded by specifying the model_id, task for which loaded
#       and number of tokens to generate
#       Use from_model_id method()

hf = HuggingFacePipeline.from_model_id(
                                      model_id= "gpt2", # "microsoft/Phi-3-mini-4k-instruct",  # 550MB
                                      task="text-generation",
                                      device=0,  # Only available if under Edit-->Notebook Settings
                                                 #  you have selected GPU. Else for CPU value is -1
                                      pipeline_kwargs={"max_new_tokens": 1020},
                                      )
# Out:
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]

# %%
# 3.0.2
question = """Describe very briefly India"""

# %%
# %%time

# 3.0.3
print(hf(question))
# Out:
# This is a friendly reminder - the current text generation call will exceed the model's predefined maximum length (1024). Depending on the model, you may observe exceptions, performance degradation, or nothing at all.
# Describe very briefly India in general which was founded on the earth's surface. The Sanskrit term for it is 'Vasti' which means sun. And of course the sun is only visible to the sun's surface. It is true that there are six classes of earth's surface, called the four solar system. All those solar systems which are on the earth, all of them are from the Sun, and therefore it is natural for them to appear from the Sun when they are in the Sunlight. So it is natural for them to show up from the sun even when they are in the Sunlight. If they look out the window of their car from the surface of the sun and there show one man who came down to the earth, of the four solar system which are on the earth, it is natural and normal for their to appear in order to be in the sunlight and to be in the sun, but they are not able or able to look out for themselves.
#
# When they are seen at night from the Sunlight, it is very natural to appear and to show them from the earth where all that is happening is being observed and is occurring. And the same thing is true for the Sunlight through which all that is happening is being observed. On the ground it is more natural for them to appear from the sun to see all that is being observed and to be in the sun. If they are not able to see some of anything appearing from the earth and not from the Sun, they would not appear for them.
#
# If a man has a very low birth weight that is not 10 grams or 15 grams, yet he is being seen from anywhere in the entire world by the earth and he would not show any difference in the brightness and brightness of the world. We cannot be seen except they are from everywhere in the entire earth, and it is natural but it is not natural.
#
# There are many myths which say that the Earth is the originator of the gods, which deny any such fact. The Earth which has been created out of the seven parts, with eight solar systems, and has been produced by the Seven Gods was the "most marvelous and holy world on the face of the earth". If a man were to try hard for the name of the gods from a distance they would find a few of the seven solar systems out there. No one would like to associate them with the Seven Gods of the Earth.
#
# But if the gods were to be believed in their true nature. If the earth were formed out of the seven parts. If they were to be believed in the same god, it would take them at least five centuries to learn to recognize that they are not different. And if the gods were to be believed in their divine nature, it would take them five centuries to learn that they are not different. And if they were to be believed in their divine nature they would take them at least five centuries to understand that they are not more common or common or common.
#
# All that is the matter. The earth was the creation of men and was a good example for all humankind, just like any other great god. When the god of mankind first appeared the earth had the same nature the sun had, but in time it was very different. When it was made it was formed into a great sun with four regions, the regions of Paradise. It looked not like a sun, the earth was not created by another being or was created from nothing or from nothing.
#
# What a gods are they? Because they are the gods of human flesh and of gods known not only the world. The earth and the cosmos were formed of the seven forces of things. There are seven forces from the sun and seven forces out of the earth, the forces of Nature, Spirit, Knowledge and the good which are manifested by the seven forces of man. They are the gods of living beings and of Gods of Nature.
#
# They have this God which resides outside the body and is with men in all their actions and in every kind of activity. He loves what men need and does the things that are needed for him and not those which are necessary for him. He creates the perfect human nature. He creates what we are or need in our needs and not that which is necessary, either because we are the gods or because we have something to do with other men. He gives birth to human life and death to man in every kind of activity.
#
# But he wants us, he cares for us, and that is what makes his design of creation. The seven forces of God were created out of man's life force, but they were not formed from other minds when it was made. When he created them through man's life force they have an inherent meaning, which it's not possible to know.
#
# If a man saw his father as just a little child then he would understand immediately, because that was what he was built out of while it was built. His conception was in control, which allowed him to know and understand where things were good and evil
# CPU times: user 12.9 s, sys: 133 ms, total: 13.1 s
# Wall time: 13.9 s

# %%
# 3.0.2 We need prompttemplate:

from langchain_core.prompts import PromptTemplate

# %%
# 3.0.3
prompt = PromptTemplate.from_template(question)

# %%
# 3.0.4
chain = prompt | hf

# %%
# %%time

# 3.0.5
chain.invoke(input = {})
# Out:
# CPU times: user 12.3 s, sys: 25.8 ms, total: 12.4 s
# Wall time: 12.4 s
# 'Describe very briefly India, China, Iran and Israel — the most dangerous, and perhaps most dangerous countries in the world, on the eve of a nuclear test. For what will it take to change such a dismal perception? And what will it take to change the attitude and the outlook, which was the very core of our nation\'s pre-eminence, for India, especially now, to see the light of day?\n\nFor I think we\'ve got five or six years. By 2017, my hope is we\'ll see, in a large, decisive way — and I think we\'ll see it as a major turning off, because we live in an age that we\'re so dependent on those people who control and control our lives, to say, "We don\'t matter!" That\'s going to take some time. What\'s the process going to be? And how do you see a political process that\'s successful, effective and will transform a country that\'s lost over the last few years? What\'s it going to take for me to do that?\n\nJIM VILLA: Okay.\n\nAMANDA DEPUTYHAN: So a long speech.\n\nAMY GOODMAN: A long speech, sir.\n\nAMANDA DEPUTYHAN: Thank you so much from Amy Van Der Sar.\n\nAMY GOODMAN: And I\'m Amy Goodman, host of Democracy Now!, thanks for being with us.\n\nAMANDA DEPUTYHAN: Thank you all very much.\n\n[break]\n\nAMY GOODMAN: Thank you, Amy Van Der Sar.\n\nAMANDA DEPUTYHAN: I\'m Amy Goodman, host of Democracy Now!, democracynow.org, where we\'re reporting on the events in Charlottesville, Virginia, where a white, National Guard member was arrested after he was allegedly "shooting and killing a demonstrator on campus." It\'s not the first time that a white nationalist has fired and wounded a white nationalist; over the past several years, there have been many people, including police officers, who have been killed in Charlottesville. A federal judge in Virginia has ordered police to investigate a "massacre of white supremacists" after multiple police officers were wounded in Charlottesville, Virginia, on Saturday morning.\n\nIt seems like you were saying, I mean, the American people, as you\'ve said, that those responsible, you know, those who are being blamed for this hatred and violence and bigotry and violence — we\'ve seen all the events that have come his way as we know it right here, across the country. So I don\'t know who it is who would just kill someone and call it an evil act, but when you\'re going to shoot white people that you see, I wouldn\'t be surprised if they\'re going to get a very big pardon or whatever.\n\nAMY GOODMAN: The National Weather Service called and called in a state fire chief for more protection, but one local official told the New Yorker, "We\'re not sure if it\'s fire or vandalism. Nobody is looking into that incident or what happened on campus."\n\nAMY GOODMAN: Talk about national security. What sort of response did National Guard members get from Charlottesville, Virginia and what are the ramifications for the ongoing debate surrounding those events. It seemed like a very high profile, though, event after a massive hate rally in Charlottesville on Saturday. There were far darker attacks on protesters but no incidents of violence on campus.\n\nHOMANSHIP DAKHAW: Our message here is that you had to stand up and you had to stand up and you had to stand up against racists, all of them, all of them.\n\nAMANDA DEPUTYHAN: And it\'s going to take those five or six years of actions that will create those conditions where we can go forward in this process, and those five or six years we will have, that will be that the country will be a better place.\n\nAMY GOODMAN: Michael Spencer, welcome to Democracy Now! Your welcome to Northamptonshire. We\'re on our way to Virginia, Virginia for the annual American Conservative Union event this evening. It\'s also a forum to learn people from all over the country about each other on national and national security matters, especially on issues of security and race and gender equality and the right to bear arms. So a lot of the conversation in Northamptonshire here is about securi ...

# %% [markdown]
# ## USing HuggingfaceHub

# %%
############ DONE ##################
