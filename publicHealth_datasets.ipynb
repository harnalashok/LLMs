# %% [markdown]
# <a href="https://colab.research.google.com/github/harnalashok/LLMs/blob/main/publicHealth_datasets.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Last amended: 15th Sep, 2025

# %% [markdown]
# # Embedders for medical domain
# See [this article](https://huggingface.co/blog/abhinand/medembed-finetuned-embedding-models-for-medical-ir)

# %% [markdown]
# ## Public Health Datasets on Huggingface

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### How to read public health datasets on Huggingface

# %%
#1.0 Install necessary datasets library
# !pip install datasets --quiet

# %%
#1.1 Call the library and read a specific dataset
from datasets import load_dataset
import pandas as pd
# Out:
# Dataset({
#     features: ['question', 'answer', 'url', 'source', 'section'],
#     num_rows: 172
# })

# %%
#1.2 Load one of the public health dataset(s)
# Load the dataset
dataset = load_dataset("xhluca/publichealth-qa", split = "test")

#1.3 Print the dataset structure
print(dataset)

# %%
#1.4 Transform to pandas and print
df = dataset.to_pandas()
print(df.head())
# Out:
#                                             question  \
# 0                       What is a novel coronavirus?
# 1  Why is the disease being called coronavirus di...
# 2  Why might someone blame or avoid individuals a...
# 3  How can people help stop stigma related to COV...
# 4  Why do some state’s COVID-19 case numbers some...
#
#                                               answer  \
# 0  A novel coronavirus is a new coronavirus that ...
# 1  On February 11, 2020 the World Health Organiza...
# 2  People in the U.S. may be worried or anxious a...
# 3  People can fight stigma by providing social su...
# 4  CDC’s overall case numbers are validated throu...
#
#                                                  url source  \
# 0  https://www.cdc.gov/coronavirus/2019-ncov/faq....    CDC
# 1  https://www.cdc.gov/coronavirus/2019-ncov/faq....    CDC
# 2  https://www.cdc.gov/coronavirus/2019-ncov/faq....    CDC
# 3  https://www.cdc.gov/coronavirus/2019-ncov/faq....    CDC
# ...

# %%
###############
