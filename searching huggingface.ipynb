# %% [markdown]
# <a href="https://colab.research.google.com/github/harnalashok/LLMs/blob/main/searching%20huggingface.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Last amended: 29th MAy, 2024
# Searching datasets/models/spaces on huggingface
# Go for Full text search

# %% [markdown]
# ## Searching [Huggingface](https://huggingface.co/)
# For Models/Datasets/Spaces

# %% [markdown]
# > 1. Access `Datasets` page (see below) by clicking [here](https://huggingface.co/datasets)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# > 2. Click on `Full text` search and enter a search string.
# Note that only `Datasets` is checked in the right-panel:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# > 3. You can also search for a multi-word string enclosed in double inverted commas:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# >4. Similarly you can search for cosmetics in `Models`:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# > 5. Similarly one search if anyone has built any `app` that pertains to cosmetics? Search `Spaces`. Here is a list of `apps`. Some of them do not work and give error. One `app` pertains to finding shops.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
############ DONE #####################
